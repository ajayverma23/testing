# %%
from langchain.prompts import PromptTemplate

image_catg = 'car'
template = """You are expert in understanding {image_catg}, we will upload a
            imagei of {image_catg} and you will have to answer any question based on the
            uploaded {image_catg} image"""
                        
input_prompt=PromptTemplate(input_variables=['image_catg'], template=template)

input_prompt.format(image_catg = image_catg)
# Out:
# 'You are expert in understanding car, we will upload a\n            imagei of car and you will have to answer any question based on the\n            uploaded car image'

# %%
from langchain.llms import LlamaCpp
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

n_gpu_layers = 40
n_batch = 512

callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])

llm = LlamaCpp(
    model_path="/content/llama-2-7b-chat.Q4_K_M.gguf",
    temperature=0.1,
    n_gpu_layers=n_gpu_layers,
    n_batch=n_batch,
    callback_manager=callback_manager,
    verbose=True,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\ajverma\AppData\Local\anaconda3\envs\langchain\lib\site-packages\langchain_community\llms\llamacpp.py:140, in LlamaCpp.validate_environment(cls, values)
#     139 try:
# --> 140     from llama_cpp import Llama, LlamaGrammar
#     141 except ImportError:
#
# ModuleNotFoundError: No module named 'llama_cpp'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 10
#       6 n_batch = 512
#       8 callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])
# ---> 10 llm = LlamaCpp(
#      11     model_path="/content/llama-2-7b-chat.Q4_K_M.gguf",
#      12     temperature=0.1,
#      13     n_gpu_layers=n_gpu_layers,
#      14     n_batch=n_batch,
# ...

# %%
#ChatModel
#TextGenerationModel
import vertexai
from vertexai.preview.language_models import TextGenerationModel

model_name="text-bison@001"; temperature=0.2; max_output_tokens=256; top_p=0.8; top_k=40
model = TextGenerationModel.from_pretrained(model_name="text-bison@001")
prompt = "What are five important things to understand about large language models?"
response = model.predict(
        prompt,
        temperature=temperature,
        max_output_tokens=max_output_tokens,
        top_p=top_p,
        top_k=top_k,
    )

response
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File c:\Users\ajverma\AppData\Local\anaconda3\envs\langchain\lib\site-packages\google\cloud\aiplatform\initializer.py:302, in _Config.project(self)
#     301 try:
# --> 302     self._set_project_as_env_var_or_google_auth_default()
#     303     project_id = self._project
#
# File c:\Users\ajverma\AppData\Local\anaconda3\envs\langchain\lib\site-packages\google\cloud\aiplatform\initializer.py:93, in _Config._set_project_as_env_var_or_google_auth_default(self)
#      92 else:
# ---> 93     credentials, project = google.auth.default()
#      94     self._credentials = self._credentials or credentials
#
# File c:\Users\ajverma\AppData\Local\anaconda3\envs\langchain\lib\site-packages\google\auth\_default.py:691, in default(scopes, request, quota_project_id, default_scopes)
#     689         return credentials, effective_project_id
# ...
